# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('olympics_cleaned_v4.csv')

# %%
df.sample(15)
# Out:
#             ID                                 Name Sex   Age  Height  Weight  \
# 209767   45484                           Han Song-I   F  19.0   186.0    65.0
# 78285    72626                        Jair K. Lynch   M  24.0   162.0    59.0
# 183967  106908                    Claus Schiprowski   M  25.0   177.0    69.0
# 86535    59207         Sergey Vladimirovich Kharkov   M  17.0   167.0    63.0
# 58044    89544                 Ariel Arnaldo Ortega   M  22.0   170.0    64.0
# 158830    2948                          Alan Almand   M  29.0   193.0    98.0
# 125077   21731                Victor Polydore Claes   M  23.0     NaN     NaN
# 44451     7824                      Samanta Bardini   F  27.0   163.0    64.0
# 115890   17745                Samuel "Sam" Campbell   M  24.0   180.0    66.0
# 129407   57668                        Dipa Karmakar   F  22.0   151.0    47.0
# 207848  102297                     Adrian D. Romero   M  19.0     NaN     NaN
# ...

# %%
df.shape
# Out:
# (219085, 12)

# %%
df.duplicated().sum()
# Out:
# 13

# %%
df.isnull().sum()
# Out:
# ID              0
# Name            0
# Sex             0
# Age          8275
# Height      48936
# Weight      50888
# NOC             0
# Year            0
# Sport           0
# Event           0
# Medal      185475
# country        21
# dtype: int64

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 219085 entries, 0 to 219084
# Data columns (total 12 columns):
#  #   Column   Non-Null Count   Dtype
# ---  ------   --------------   -----
#  0   ID       219085 non-null  int64
#  1   Name     219085 non-null  object
#  2   Sex      219085 non-null  object
#  3   Age      210810 non-null  float64
#  4   Height   170149 non-null  float64
#  5   Weight   168197 non-null  float64
#  6   NOC      219085 non-null  object
#  7   Year     219085 non-null  int64
#  8   Sport    219085 non-null  object
#  9   Event    219085 non-null  object
#  10  Medal    33610 non-null   object
#  11  country  219064 non-null  object
# dtypes: float64(3), int64(2), object(7)
# memory usage: 20.1+ MB

# %%
df[df.duplicated()]
# Out:
#             ID                                               Name Sex   Age  \
# 23561     8683                                   Jacques Baudrier   M  28.0
# 25631    26037          Jean Alfred Octave de Chabannes la Palice   M  29.0
# 28562    65581                                    Jacques la Caze   M   NaN
# 28823    67210                               Albert Eugne Laverne   M  34.0
# 28863    67492                       Gabriel Charles Jean Le Bret   M  27.0
# 29791    75648                             Charles William Martin   M  71.0
# 32485   119448                                           Texier I   M   NaN
# 32486   119448                                           Texier I   M   NaN
# 32487   119448                                           Texier I   M   NaN
# 32493   119449                                          Texier II   M   NaN
# 32494   119449                                          Texier II   M   NaN
# ...

# %% [markdown]
# ### Drop the duplicated rows

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# 0

# %%
df.shape
# Out:
# (219072, 12)

# %%
df.head(10)
# Out:
#      ID           Name Sex   Age  Height  Weight  NOC  Year       Sport  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  CHN  1992  Basketball
# 1     2       A Lamusi   M  23.0   170.0    60.0  CHN  2012        Judo
# 2   602  Abudoureheman   M  22.0   182.0    75.0  CHN  2000      Boxing
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  CHN  2004   Wrestling
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  CHN  2016    Swimming
# 5  1464      Ai Yanhan   F  14.0   168.0    54.0  CHN  2016    Swimming
# 6  3611    An Zhongxin   F  23.0   170.0    65.0  CHN  1996    Softball
# 7  3611    An Zhongxin   F  27.0   170.0    65.0  CHN  2000    Softball
# 8  4639   Ao Changrong   M  25.0   173.0    71.0  CHN  2008      Hockey
# 9  4641       Ao Tegen   M  21.0   181.0    90.0  CHN  1996        Judo
#
#                                              Event   Medal country
# 0                      Basketball Men's Basketball     NaN   China
# ...

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Drop all the Nan values (missing values from the age, height and weight column)

# %%
df.isnull().sum()
# Out:
# ID              0
# Name            0
# Sex             0
# Age          8268
# Height      48923
# Weight      50875
# NOC             0
# Year            0
# Sport           0
# Event           0
# Medal      185462
# country        21
# dtype: int64

# %%
df = df.dropna(subset = ['Age','Height','Weight','country'])
df.sample(8)
# Out:
#             ID                             Name Sex   Age  Height  Weight  \
# 102080   51267                      Marc Huster   M  26.0   174.0    82.5
# 214689   95780                      Martin Polk   M  21.0   178.0    84.0
# 157234  130364                  Hans Klas Wikne   M  50.0   181.0    75.0
# 183608   86792                      Jrgen Nolte   M  24.0   178.0    68.0
# 62458   109418  Yevgeny Nikolayevich Shchetinin   M  26.0   170.0    62.0
# 93746    90151                       Eszter vry   F  15.0   152.0    42.0
# 34310     8068       Alejandro Barrenechea Jayo   M  24.0   164.0    67.0
# 18915     4876               Rodica Arba-Pucatu   F  26.0   179.0    75.0
#
#         NOC  Year          Sport                                  Event  \
# 102080  GER  1996  Weightlifting  Weightlifting Men's Light-Heavyweight
# 214689  CZE  2000        Cycling  Cycling Men's 1,000 metres Time Trial
# 157234  SWE  1964  Equestrianism     Equestrianism Mixed Dressage, Team
# ...

# %%
df.isnull().sum()
# Out:
# ID              0
# Name            0
# Sex             0
# Age             0
# Height          0
# Weight          0
# NOC             0
# Year            0
# Sport           0
# Event           0
# Medal      140959
# country         0
# dtype: int64

# %%
df.shape
# Out:
# (166222, 12)

# %% [markdown]
# ## Medal Colmun

# %%
df.head()
# Out:
#      ID           Name Sex   Age  Height  Weight  NOC  Year       Sport  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  CHN  1992  Basketball
# 1     2       A Lamusi   M  23.0   170.0    60.0  CHN  2012        Judo
# 2   602  Abudoureheman   M  22.0   182.0    75.0  CHN  2000      Boxing
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  CHN  2004   Wrestling
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  CHN  2016    Swimming
#
#                                       Event Medal country
# 0               Basketball Men's Basketball   NaN   China
# 1              Judo Men's Extra-Lightweight   NaN   China
# 2                 Boxing Men's Middleweight   NaN   China
# 3  Wrestling Men's Lightweight, Greco-Roman   NaN   China
# 4     Swimming Women's 200 metres Freestyle   NaN   China

# %%
df['Medal'].value_counts()
# Out:
# Medal
# Bronze    8546
# Gold      8512
# Silver    8205
# Name: count, dtype: int64

# %%
df.replace()
# Out:
#             ID                    Name Sex   Age  Height  Weight  NOC  Year  \
# 0            1               A Dijiang   M  24.0   180.0    80.0  CHN  1992
# 1            2                A Lamusi   M  23.0   170.0    60.0  CHN  2012
# 2          602           Abudoureheman   M  22.0   182.0    75.0  CHN  2000
# 3         1463               Ai Linuer   M  25.0   160.0    62.0  CHN  2004
# 4         1464               Ai Yanhan   F  14.0   168.0    54.0  CHN  2016
# ...        ...                     ...  ..   ...     ...     ...  ...   ...
# 219078  119487  Likeleli Alinah Thamae   F  22.0   170.0    49.0  LES  2000
# 219080  120575         Mamorallo Tjoka   F  23.0   150.0    56.0  LES  2008
# 219081  120575         Mamorallo Tjoka   F  27.0   150.0    56.0  LES  2012
# 219083  122215              Lefa Tsapi   M  23.0   170.0    63.0  LES  1984
# 219084  122299           Mosolesa Tsie   M  20.0   175.0    75.0  LES  2000
#
# ...

# %%
df['Medal'].fillna(0,inplace = True)

# %%
df['Medal'].value_counts()
# Out:
# Medal
# 0         140959
# Bronze      8546
# Gold        8512
# Silver      8205
# Name: count, dtype: int64

# %%
df.replace ({'Gold': '1' , 'Silver': '2', 'Bronze': '3'},inplace = True)

# %%
df['Medal'].value_counts()
# Out:
# Medal
# 0    140959
# 3      8546
# 1      8512
# 2      8205
# Name: count, dtype: int64

# %%
df.head(10)
# Out:
#      ID           Name Sex   Age  Height  Weight  NOC  Year       Sport  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  CHN  1992  Basketball
# 1     2       A Lamusi   M  23.0   170.0    60.0  CHN  2012        Judo
# 2   602  Abudoureheman   M  22.0   182.0    75.0  CHN  2000      Boxing
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  CHN  2004   Wrestling
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  CHN  2016    Swimming
# 5  1464      Ai Yanhan   F  14.0   168.0    54.0  CHN  2016    Swimming
# 6  3611    An Zhongxin   F  23.0   170.0    65.0  CHN  1996    Softball
# 7  3611    An Zhongxin   F  27.0   170.0    65.0  CHN  2000    Softball
# 8  4639   Ao Changrong   M  25.0   173.0    71.0  CHN  2008      Hockey
# 9  4641       Ao Tegen   M  21.0   181.0    90.0  CHN  1996        Judo
#
#                                              Event Medal country
# 0                      Basketball Men's Basketball     0   China
# ...

# %% [markdown]
# ## Categorical columns

# %%
df['Sex'].value_counts()
# Out:
# Sex
# M    112960
# F     53262
# Name: count, dtype: int64

# %%
df['NOC'].value_counts()
# Out:
# NOC
# USA    10922
# GBR     6850
# FRA     6262
# AUS     6207
# ITA     5679
#        ...
# SAA        3
# SSD        3
# YMD        2
# UAR        1
# NFL        1
# Name: count, Length: 223, dtype: int64

# %%
df['Sport'].value_counts()
# Out:
# Sport
# Athletics                32203
# Swimming                 18644
# Gymnastics               18263
# Rowing                    7789
# Cycling                   7762
# Shooting                  7245
# Fencing                   6530
# Canoeing                  5548
# Wrestling                 5183
# Sailing                   4831
# Equestrianism             4553
# Football                  4443
# Boxing                    4362
# Hockey                    4264
# Basketball                3668
# Judo                      3362
# Handball                  3319
# Volleyball                3277
# Weightlifting             2958
# Water Polo                2719
# Diving                    2010
# Tennis                    2008
# Archery                   1883
# Table Tennis              1749
# Badminton                 1343
# Modern Pentathlon         1259
# Synchronized Swimming      849
# Baseball                   846
# Rhythmic Gymnastics        615
# Taekwondo                  596
# ...

# %%
df['Event'].value_counts()
# Out:
# Event
# Football Men's Football                              3459
# Hockey Men's Hockey                                  2874
# Basketball Men's Basketball                          2461
# Water Polo Men's Water Polo                          2231
# Cycling Men's Road Race, Individual                  2099
#                                                      ...
# Art Competitions Mixed Sculpturing                      1
# Sailing Mixed 6.5 metres                                1
# Art Competitions Mixed Music                            1
# Art Competitions Mixed Sculpturing, Unknown Event       1
# Tennis Men's Singles, Covered Courts                    1
# Name: count, Length: 467, dtype: int64

# %%
df['country'].value_counts()
# Out:
# country
# USA            10922
# Germany        10066
# Russia          7816
# UK              6850
# France          6262
#                ...
# Kiribati          11
# Brunei             9
# Kosovo             8
# Timor-Leste        5
# South Sudan        3
# Name: count, Length: 205, dtype: int64

# %% [markdown]
# ## Categorical column preprocessing

# %%
from sklearn.preprocessing import LabelEncoder

# %%
df.head()
# Out:
#      ID           Name Sex   Age  Height  Weight  NOC  Year       Sport  \
# 0     1      A Dijiang   M  24.0   180.0    80.0  CHN  1992  Basketball
# 1     2       A Lamusi   M  23.0   170.0    60.0  CHN  2012        Judo
# 2   602  Abudoureheman   M  22.0   182.0    75.0  CHN  2000      Boxing
# 3  1463      Ai Linuer   M  25.0   160.0    62.0  CHN  2004   Wrestling
# 4  1464      Ai Yanhan   F  14.0   168.0    54.0  CHN  2016    Swimming
#
#                                       Event Medal country
# 0               Basketball Men's Basketball     0   China
# 1              Judo Men's Extra-Lightweight     0   China
# 2                 Boxing Men's Middleweight     0   China
# 3  Wrestling Men's Lightweight, Greco-Roman     0   China
# 4     Swimming Women's 200 metres Freestyle     0   China

# %%
df = df.drop(columns = ['Name','ID'])
df
# Out:
#        Sex   Age  Height  Weight  NOC  Year       Sport  \
# 0        M  24.0   180.0    80.0  CHN  1992  Basketball
# 1        M  23.0   170.0    60.0  CHN  2012        Judo
# 2        M  22.0   182.0    75.0  CHN  2000      Boxing
# 3        M  25.0   160.0    62.0  CHN  2004   Wrestling
# 4        F  14.0   168.0    54.0  CHN  2016    Swimming
# ...     ..   ...     ...     ...  ...   ...         ...
# 219078   F  22.0   170.0    49.0  LES  2000   Taekwondo
# 219080   F  23.0   150.0    56.0  LES  2008   Athletics
# 219081   F  27.0   150.0    56.0  LES  2012   Athletics
# 219083   M  23.0   170.0    63.0  LES  1984      Boxing
# 219084   M  20.0   175.0    75.0  LES  2000      Boxing
#
#                                            Event Medal  country
# 0                    Basketball Men's Basketball     0    China
# 1                   Judo Men's Extra-Lightweight     0    China
# 2                      Boxing Men's Middleweight     0    China
# ...

# %%
df.replace({'M': '0', 'F': '1'},inplace = True)
df
# Out:
#        Sex   Age  Height  Weight  NOC  Year       Sport  \
# 0        0  24.0   180.0    80.0  CHN  1992  Basketball
# 1        0  23.0   170.0    60.0  CHN  2012        Judo
# 2        0  22.0   182.0    75.0  CHN  2000      Boxing
# 3        0  25.0   160.0    62.0  CHN  2004   Wrestling
# 4        1  14.0   168.0    54.0  CHN  2016    Swimming
# ...     ..   ...     ...     ...  ...   ...         ...
# 219078   1  22.0   170.0    49.0  LES  2000   Taekwondo
# 219080   1  23.0   150.0    56.0  LES  2008   Athletics
# 219081   1  27.0   150.0    56.0  LES  2012   Athletics
# 219083   0  23.0   170.0    63.0  LES  1984      Boxing
# 219084   0  20.0   175.0    75.0  LES  2000      Boxing
#
#                                            Event Medal  country
# 0                    Basketball Men's Basketball     0    China
# 1                   Judo Men's Extra-Lightweight     0    China
# 2                      Boxing Men's Middleweight     0    China
# ...

# %%
label_encoder = LabelEncoder()
df['NOC_encoder'] = label_encoder.fit_transform(df['NOC'])

# %%
df
# Out:
#        Sex   Age  Height  Weight  NOC  Year       Sport  \
# 0        0  24.0   180.0    80.0  CHN  1992  Basketball
# 1        0  23.0   170.0    60.0  CHN  2012        Judo
# 2        0  22.0   182.0    75.0  CHN  2000      Boxing
# 3        0  25.0   160.0    62.0  CHN  2004   Wrestling
# 4        1  14.0   168.0    54.0  CHN  2016    Swimming
# ...     ..   ...     ...     ...  ...   ...         ...
# 219078   1  22.0   170.0    49.0  LES  2000   Taekwondo
# 219080   1  23.0   150.0    56.0  LES  2008   Athletics
# 219081   1  27.0   150.0    56.0  LES  2012   Athletics
# 219083   0  23.0   170.0    63.0  LES  1984      Boxing
# 219084   0  20.0   175.0    75.0  LES  2000      Boxing
#
#                                            Event Medal  country  NOC_encoder
# 0                    Basketball Men's Basketball     0    China           40
# 1                   Judo Men's Extra-Lightweight     0    China           40
# ...

# %%
df['Sport_encoder'] = label_encoder.fit_transform(df['Sport'])

# %%
df['Event_encoder'] = label_encoder.fit_transform(df['Event'])

# %%
df['country_encoder'] = label_encoder.fit_transform(df['country'])

# %%
df.drop(columns = ['NOC','Sport','Event','country'],inplace = True)

# %%
df
# Out:
#        Sex   Age  Height  Weight  Year Medal  NOC_encoder  Sport_encoder  \
# 0        0  24.0   180.0    80.0  1992     0           40              5
# 1        0  23.0   170.0    60.0  2012     0           40             20
# 2        0  22.0   182.0    75.0  2000     0           40              7
# 3        0  25.0   160.0    62.0  2004     0           40             42
# 4        1  14.0   168.0    54.0  2016     0           40             31
# ...     ..   ...     ...     ...   ...   ...          ...            ...
# 219078   1  22.0   170.0    49.0  2000     0          116             34
# 219080   1  23.0   150.0    56.0  2008     0          116              2
# 219081   1  27.0   150.0    56.0  2012     0          116              2
# 219083   0  23.0   170.0    63.0  1984     0          116              7
# 219084   0  20.0   175.0    75.0  2000     0          116              7
#
#         Event_encoder  country_encoder
# 0                 100               39
# ...

# %%
x = df[['Sex','Age','Height','Weight','Year','NOC_encoder','Sport_encoder','Event_encoder','country_encoder']]
y = df['Medal']

# %%
print(x.shape)
print(y.shape)
# Out:
# (166222, 9)
# (166222,)

# %% [markdown]
# ## Models

# %%
from sklearn.model_selection import train_test_split
from sklearn.ensemble import RandomForestRegressor

# %%
x_train, x_test ,y_train,y_test = train_test_split(x,y,test_size = 0.2, random_state = 42)
print(x_train.shape)
print(y_train.shape)
print(x_test.shape)
print(y_test.shape)
# Out:
# (132977, 9)
# (132977,)
# (33245, 9)
# (33245,)

# %%
y_train = y_train.astype(int)
y_test = y_test.astype(int)

# %%
#x_train.to_csv('x_train.csv')
#y_train.to_csv('y_train.csv')
#x_test.to_csv('x_test.csv')
#y_test.to_csv('y_test.csv')

# %% [markdown]
# ## Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
from sklearn.metrics import accuracy_score


rf_classifier = RandomForestClassifier(n_estimators=100, random_state=42)
rf_classifier.fit(x_train, y_train)
predictions = rf_classifier.predict(x_test)
accuracy = accuracy_score(y_test, predictions)
print("Accuracy:", accuracy)
# Out:
# Accuracy: 0.8864791697999699

# %%
from sklearn.metrics import confusion_matrix
from sklearn.metrics import classification_report
import matplotlib.pyplot as plt
import seaborn as sns

cm = confusion_matrix(y_test,predictions)
classes = np.unique(y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()
# Out:
# [[27844   171   141   181]
#  [  774   741    83    62]
#  [  964    96   450    66]
#  [ 1118    61    57   436]]

# %% [markdown]
# # Gradient Boosting

# %%
from sklearn.ensemble import GradientBoostingClassifier
from sklearn.metrics import accuracy_score

gb_classifier = GradientBoostingClassifier(n_estimators = 100, max_depth = 5)


gb_classifier.fit(x_train, y_train)
train_predictions = gb_classifier.predict(x_train)
train_accuracy = accuracy_score(y_train, train_predictions)

print("Training Accuracy:", train_accuracy)

test_predictions = gb_classifier.predict(x_test)
test_accuracy = accuracy_score(y_test, test_predictions)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.8596599411928378
# Testing Accuracy: 0.8623552413896827

# %%
cm = confusion_matrix(y_test,test_predictions)
classes = np.unique(y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %% [markdown]
# # XG Boost

# %%
import xgboost as xgb

x_train['Sex'] = label_encoder.fit_transform(x_train['Sex'])
x_test['Sex'] = label_encoder.fit_transform(x_test['Sex'])


xgb_classifier = xgb.XGBClassifier(n_estimators=100, max_depth=5)

xgb_classifier.fit(x_train, y_train)

train_predictions = xgb_classifier.predict(x_train)
train_accuracy = accuracy_score(y_train, train_predictions)
print("Training Accuracy:", train_accuracy)

test_predictions = xgb_classifier.predict(x_test)


test_accuracy = accuracy_score(y_test, test_predictions)
print("Testing Accuracy:", test_accuracy)
# Out:
# Training Accuracy: 0.8613068425366793
# Testing Accuracy: 0.8637689878177169

# %%
cm = confusion_matrix(y_test,test_predictions)
classes = np.unique(y_test)
plt.figure(figsize=(8, 6))
sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=classes, yticklabels=classes)
plt.xlabel('Predicted labels')
plt.ylabel('True labels')
plt.title('Confusion Matrix')
plt.show()

# %%
from keras.utils import to_categorical
num_classes = 4
ytrain = to_categorical(y_train, num_classes=num_classes)
ytest = to_categorical(y_test, num_classes=num_classes)

print(x_train.shape)
# Out:
# (132977, 9)

# %% [markdown]
# ## Neural Network

# %%
from keras.layers import Dropout
from keras.optimizers import Adam
from keras.callbacks import EarlyStopping
from keras.models import Sequential
from keras.layers import Flatten, Dense


model = Sequential()
model.add(Flatten(input_shape=(9,)))
model.add(Dropout(0.5))
model.add(Dense(256, activation='relu'))
model.add(Dense(128, activation='relu'))
model.add(Dense(64, activation='relu'))
model.add(Dense(32, activation='relu'))
model.add(Dense(4, activation='softmax'))


optimizer = Adam(learning_rate=0.001)

model.compile(optimizer=optimizer,
              loss='categorical_crossentropy',
              metrics=['accuracy'])


early_stopping = EarlyStopping(monitor='val_loss', patience=15, restore_best_weights=True)


history = model.fit(x_train, ytrain,
                    validation_split=0.1,
                    batch_size=15,
                    epochs=20,
                    callbacks=[early_stopping],
                    verbose=1)


test_loss, test_acc = model.evaluate(x_test, ytest)
print("Test accuracy:", test_acc * 100)
print('Test loss:', test_loss)
# Out:
# Epoch 1/20
# /Users/pradyot/anaconda3/lib/python3.11/site-packages/keras/src/layers/reshaping/flatten.py:37: UserWarning: Do not pass an `input_shape`/`input_dim` argument to a layer. When using Sequential models, prefer using an `Input(shape)` object as the first layer in the model instead.
#   super().__init__(**kwargs)
# 7979/7979 ━━━━━━━━━━━━━━━━━━━━ 8s 869us/step - accuracy: 0.8235 - loss: 1.5071 - val_accuracy: 0.8472 - val_loss: 0.5953
# Epoch 2/20
# 7979/7979 ━━━━━━━━━━━━━━━━━━━━ 7s 845us/step - accuracy: 0.8443 - loss: 0.6049 - val_accuracy: 0.8472 - val_loss: 0.5955
# Epoch 3/20
# 7979/7979 ━━━━━━━━━━━━━━━━━━━━ 7s 921us/step - accuracy: 0.8469 - loss: 0.5963 - val_accuracy: 0.8472 - val_loss: 0.5954
# Epoch 4/20
# 7979/7979 ━━━━━━━━━━━━━━━━━━━━ 7s 915us/step - accuracy: 0.8453 - loss: 0.6008 - val_accuracy: 0.8472 - val_loss: 0.5953
# Epoch 5/20
# 7979/7979 ━━━━━━━━━━━━━━━━━━━━ 6s 802us/step - accuracy: 0.8468 - loss: 0.5967 - val_accuracy: 0.8472 - val_loss: 0.5953
# ...

# %%
model.summary()
# Out:
# Model: "sequential"
# ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━┓
# ┃ Layer (type)                    ┃ Output Shape           ┃       Param # ┃
# ┡━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━┩
# │ flatten (Flatten)               │ (None, 9)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dropout (Dropout)               │ (None, 9)              │             0 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense (Dense)                   │ (None, 256)            │         2,560 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_1 (Dense)                 │ (None, 128)            │        32,896 │
# ├─────────────────────────────────┼────────────────────────┼───────────────┤
# │ dense_2 (Dense)                 │ (None, 64)             │         8,256 │
# ...
